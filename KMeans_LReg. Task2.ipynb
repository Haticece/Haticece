# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# /

# %%
import os
print(os.path.expanduser("~"))
# Out:
# /Users/haticecakir

# %%
haticenin_verisi = pd.read_csv("/Users/haticecakir/Downloads/İllere_ve_cinsiyete_göre_yaşam_süresi.csv")
haticenin_verisi
# Out:
#     Pl.Kod_Şehir  Ortalama  Erkek  Kadın
# 0              1      76.8   74.0   79.6
# 1              2      78.7   76.4   81.0
# 2              3      76.9   74.5   79.4
# 3              4      76.9   74.5   79.4
# 4              5      78.1   75.4   80.9
# ..           ...       ...    ...    ...
# 76            77      77.9   75.1   80.9
# 77            78      78.0   75.3   80.8
# 78            79      76.1   73.2   79.1
# 79            80      77.0   74.3   79.8
# 80            81      77.4   74.6   80.3
#
# [81 rows x 4 columns]

# %%
import matplotlib .pyplot as plt
plt.scatter(haticenin_verisi["Kadın"], haticenin_verisi["Erkek"], color = "purple")
plt.xlabel("Kadın")
plt.ylabel("Erkek")
plt.title ("Cinsiyete Göre Yaşam Süresi 2021-2023")
plt.show()

# %%
model.fit(haticenin_verisi[["Kadın"]], haticenin_verisi["Erkek"])
# Out:
# LinearRegression()

# %%
tahmin_edilen_degerler = model.predict(haticenin_verisi[["Kadın"]])
tahmin_edilen_degerler
# Out:
# array([74.48014497, 75.50070347, 74.3343509 , 74.3343509 , 75.42780644,
#        76.08387976, 75.57360051, 76.15677679, 75.50070347, 74.91752719,
#        75.13621829, 76.01098272, 75.13621829, 75.93808569, 76.22967383,
#        75.06332126, 75.28201237, 75.28201237, 75.79229161, 75.42780644,
#        75.28201237, 74.77173312, 75.28201237, 76.01098272, 74.84463015,
#        75.13621829, 73.82407165, 76.52126197, 76.22967383, 76.3754679 ,
#        74.18855683, 75.71939458, 75.20911533, 75.71939458, 75.57360051,
#        75.50070347, 75.06332126, 74.99042422, 74.91752719, 75.20911533,
#        74.91752719, 75.06332126, 74.18855683, 75.93808569, 74.69883608,
#        75.06332126, 76.30257086, 76.59415901, 74.69883608, 74.69883608,
#        75.28201237, 75.64649754, 76.44836494, 74.84463015, 74.91752719,
#        75.3549094 , 75.28201237, 75.28201237, 74.69883608, 74.91752719,
#        76.30257086, 77.3960264 , 74.69883608, 75.28201237, 74.62593904,
# ...

# %%
model.coef_, model.intercept_
# Out:
# (array([0.72897036]), np.float64(16.454104580985174))

# %%
model.predict([[1]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([17.18307494])

# %%
plt.scatter(haticenin_verisi["Kadın"], haticenin_verisi["Erkek"], color="purple")
plt.plot(haticenin_verisi["Kadın"], tahmin_edilen_degerler, color="green")
plt.xlabel("Kadın")
plt.ylabel("Erkek")
plt.title("Cinsiyete Göre Yaşam Süresi 2021-2023")
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(haticenin_verisi[['Kadın','Erkek']])
haticenin_verisi['Küme'] = kmeans.predict(haticenin_verisi[['Kadın','Erkek']])
haticenin_verisi
# Out:
#     Pl.Kod_Şehir  Ortalama  Erkek  Kadın  Küme
# 0              1      76.8   74.0   79.6     1
# 1              2      78.7   76.4   81.0     0
# 2              3      76.9   74.5   79.4     1
# 3              4      76.9   74.5   79.4     1
# 4              5      78.1   75.4   80.9     4
# ..           ...       ...    ...    ...   ...
# 76            77      77.9   75.1   80.9     4
# 77            78      78.0   75.3   80.8     4
# 78            79      76.1   73.2   79.1     3
# 79            80      77.0   74.3   79.8     1
# 80            81      77.4   74.6   80.3     1
#
# [81 rows x 5 columns]

# %%
plt.scatter(haticenin_verisi["Kadın"], haticenin_verisi["Erkek"], c=haticenin_verisi ['Küme'])
plt.xlabel("Kadın")
plt.ylabel("Erkek")
plt.title ("Cinsiyete Göre Yaşam Süresi 2021-2023")
plt.show()

# %%
plt.scatter(haticenin_verisi["Kadın"], haticenin_verisi["Erkek"], c=haticenin_verisi ['Küme'])
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], c='red')
plt.xlabel("Kadın")
plt.ylabel("Erkek")
plt.title ("Cinsiyete Göre Yaşam Süresi 2021-2023")
plt.show()
